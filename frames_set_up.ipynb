# %% [markdown]
# ## Create Frames for each video
#
# This script will create the frames for each video, that will help us in the future with the following steps.

# %%
# Install the ffmpeg library
! pip install ffmpeg-python;
# Out:
# Requirement already satisfied: ffmpeg-python in /Users/stamatiosorphanos/miniconda3/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: future in /Users/stamatiosorphanos/miniconda3/lib/python3.10/site-packages (from ffmpeg-python) (0.18.3)

# %%
# Import the libraries
import ffmpeg
import shutil, os, random
import time
from pathlib import Path

# %% [markdown]
# #### Create the folders that contains the frames for each video

# %%
# Loop through all the video clips names 
base_path = '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal'
videos_path = '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos'

# Create a frames folder for cleaner project
frames_path =  '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames'
os.makedirs(frames_path)


for video in os.listdir(videos_path):
  # Define the name of the folder for each video clips frames
  base_video_name = video.lower().replace('.mp4', '').replace('-', ' ').split(' ')
  folder_name_lst = base_video_name if len(base_video_name) < 4 else base_video_name[2:]
  folder_name = ' '.join(folder_name_lst).replace(' ', '_')

  # Create the directory for the frames
  os.makedirs(os.path.join(frames_path, folder_name))
  
  # Get the input video from the videos path
  input_file = ffmpeg.input(os.path.join(videos_path, video))

  # Create the output images in the new directory we made just above
  output_file_pattern = os.path.join(os.path.join(frames_path, folder_name), 'frame_%d.png')

  # Check how long is a video to take a custom frequency for each video
  probe = ffmpeg.probe(os.path.join(videos_path, video))
  video_info = next((stream for stream in probe['streams'] if stream['codec_type'] == 'video'), None)
  duration = float(video_info['duration'])

  # Based on the duration of the video we have a different frame frequency
  # Short video duration -> High frequency
  # Long  video duration -> Low frequency
  if (duration >= 300):
    fps = 'fps=0.5'
  elif (duration < 300 and duration >= 200):
    fps = 'fps=1'
  else:
    fps = 'fps=2'

  # Get two frames per second of the video clip
  output = ffmpeg.output(input_file, output_file_pattern, vf=fps, start_number=0)
  ffmpeg.run(output)
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Imagine-Dragons-Believer.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-04-15T01:19:57.000000Z
#   Duration: 00:03:36.55, start: 0.000000, bitrate: 288 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 237 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2022-04-15T01:19:57.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/14/2022.
#     Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 47 kb/s (default)
#     Metadata:
#       creation_time   : 2022-04-15T01:19:57.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/14/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148330000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/imagine_dragons_believer/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2022-04-15T01:19:57.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/14/2022.
#       encoder         : Lavc58.54.100 png
# frame=  217 fps=0.0 q=-0.0 Lsize=N/A time=00:03:37.00 bitrate=N/A speed= 396x
# video:32551kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Post-Malone-Circles.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-05-18T22:51:46.000000Z
#   Duration: 00:03:46.35, start: 0.000000, bitrate: 252 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 201 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2023-05-18T22:51:46.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/18/2023.
#     Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 47 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-18T22:51:46.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/18/2023.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148598000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/post_malone_circles/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2023-05-18T22:51:46.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/18/2023.
#       encoder         : Lavc58.54.100 png
# frame=  226 fps=0.0 q=-0.0 Lsize=N/A time=00:03:46.00 bitrate=N/A speed= 322x
# video:41963kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Elton-John-Dua-Lipa-Cold-Heart.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-09-24T04:15:33.000000Z
#   Duration: 00:04:14.17, start: 0.000000, bitrate: 370 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 319 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2022-09-24T04:15:33.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/23/2022.
#     Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 47 kb/s (default)
#     Metadata:
#       creation_time   : 2022-09-24T04:15:33.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/23/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1480e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/dua_lipa_cold_heart/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2022-09-24T04:15:33.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/23/2022.
#       encoder         : Lavc58.54.100 png
# frame=  254 fps=0.0 q=-0.0 Lsize=N/A time=00:04:14.00 bitrate=N/A speed= 287x
# video:83303kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Camila-Cabello-Bam-Bam.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-03-05T02:45:21.000000Z
#   Duration: 00:04:16.09, start: 0.000000, bitrate: 338 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x240 [SAR 1:1 DAR 8:3], 206 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-05T02:45:21.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/04/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-03-05T02:45:21.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/04/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1384e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/bam_bam/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x240 [SAR 1:1 DAR 8:3], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-05T02:45:21.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/04/2022.
#       encoder         : Lavc58.54.100 png
# frame=  256 fps=0.0 q=-0.0 Lsize=N/A time=00:04:16.00 bitrate=N/A speed= 407x
# video:47097kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Farruko-Pepas.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-03-02T12:33:46.000000Z
#   Duration: 00:04:53.92, start: 0.000000, bitrate: 537 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x252 [SAR 1:1 DAR 160:63], 406 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-02T12:33:46.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/02/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-03-02T12:33:46.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/02/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x150768000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/farruko_pepas/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x252 [SAR 1:1 DAR 160:63], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-02T12:33:46.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/02/2022.
#       encoder         : Lavc58.54.100 png
# frame=  294 fps=0.0 q=-0.0 Lsize=N/A time=00:04:54.00 bitrate=N/A speed= 341x
# video:62254kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Elley-Duh-MIDDLE-OF-THE-NIGHT.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-06-19T03:08:39.000000Z
#   Duration: 00:03:10.40, start: 0.000000, bitrate: 408 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 276 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2022-06-19T03:08:39.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/18/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-06-19T03:08:39.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/18/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x108108000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/middle_of_the_night/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn, 2 tbc (default)
#     Metadata:
#       creation_time   : 2022-06-19T03:08:39.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/18/2022.
#       encoder         : Lavc58.54.100 png
# frame=  381 fps=0.0 q=-0.0 Lsize=N/A time=00:03:10.50 bitrate=N/A speed= 201x
# video:86287kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Cheat-Codes-No-Promises-ft-Demi-Lovato.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2020-02-23T19:57:40.000000Z
#   Duration: 00:03:44.54, start: 0.000000, bitrate: 317 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 186 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2020-02-23T19:57:40.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/23/2020.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2020-02-23T19:57:40.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/23/2020.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1282c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/no_promises_ft_demi_lovato/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2020-02-23T19:57:40.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/23/2020.
#       encoder         : Lavc58.54.100 png
# frame=  225 fps=0.0 q=-0.0 Lsize=N/A time=00:03:45.00 bitrate=N/A speed= 320x
# video:31325kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Kali-Uchis-telepat-a.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-02-12T04:10:41.000000Z
#   Duration: 00:02:49.92, start: 0.000000, bitrate: 227 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 176 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2022-02-12T04:10:41.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/11/2022.
#     Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2022-02-12T04:10:41.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/11/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1183a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/telepat_a/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn, 2 tbc (default)
#     Metadata:
#       creation_time   : 2022-02-12T04:10:41.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/11/2022.
#       encoder         : Lavc58.54.100 png
# frame=  340 fps=0.0 q=-0.0 Lsize=N/A time=00:02:50.00 bitrate=N/A speed= 190x
# video:83652kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Taylor-Swift-The-Man.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-06-18T01:22:21.000000Z
#   Duration: 00:04:14.72, start: 0.000000, bitrate: 278 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 228 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2022-06-18T01:22:21.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/17/2022.
#     Stream #0:1(und): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 47 kb/s (default)
#     Metadata:
#       creation_time   : 2022-06-18T01:22:21.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/17/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1402d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/the_man/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2022-06-18T01:22:21.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/17/2022.
#       encoder         : Lavc58.54.100 png
# frame=  255 fps=0.0 q=-0.0 Lsize=N/A time=00:04:15.00 bitrate=N/A speed= 364x
# video:65790kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Taylor-Swift-You-Need-To-Calm-Down.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-02-18T03:22:35.000000Z
#   Duration: 00:03:30.42, start: 0.000000, bitrate: 371 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 320 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2023-02-18T03:22:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2023.
#     Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 47 kb/s (default)
#     Metadata:
#       creation_time   : 2023-02-18T03:22:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2023.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1402d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/you_need_to_calm_down/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2023-02-18T03:22:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2023.
#       encoder         : Lavc58.54.100 png
# frame=  210 fps=0.0 q=-0.0 Lsize=N/A time=00:03:30.00 bitrate=N/A speed= 323x
# video:70394kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Joji-Glimpse-of-Us.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-10-09T11:25:40.000000Z
#   Duration: 00:03:54.03, start: 0.000000, bitrate: 404 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 480x360 [SAR 1:1 DAR 4:3], 272 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2022-10-09T11:25:40.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/09/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-10-09T11:25:40.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/09/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x130280000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/of_us/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 480x360 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2022-10-09T11:25:40.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/09/2022.
#       encoder         : Lavc58.54.100 png
# frame=  234 fps=0.0 q=-0.0 Lsize=N/A time=00:03:54.00 bitrate=N/A speed= 402x
# video:33512kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/DJ-Khaled-I-m-The-One.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2021-09-04T23:05:24.000000Z
#   Duration: 00:05:21.88, start: 0.000000, bitrate: 503 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 371 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2021-09-04T23:05:24.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/04/2021.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2021-09-04T23:05:24.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/04/2021.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1483c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/i_m_the_one/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 0.50 fps, 0.50 tbn, 0.50 tbc (default)
#     Metadata:
#       creation_time   : 2021-09-04T23:05:24.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/04/2021.
#       encoder         : Lavc58.54.100 png
# frame=  161 fps=0.0 q=-0.0 Lsize=N/A time=00:05:22.00 bitrate=N/A speed= 358x
# video:47584kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Ed-Sheeran-Shivers.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-06-06T00:23:32.000000Z
#   Duration: 00:03:57.80, start: 0.000000, bitrate: 357 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x338 [SAR 1:1 DAR 320:169], 226 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2023-06-06T00:23:32.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/05/2023.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2023-06-06T00:23:32.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/05/2023.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1285a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/ed_sheeran_shivers/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x338 [SAR 1:1 DAR 320:169], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2023-06-06T00:23:32.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/05/2023.
#       encoder         : Lavc58.54.100 png
# frame=  238 fps=0.0 q=-0.0 Lsize=N/A time=00:03:58.00 bitrate=N/A speed= 374x
# video:54908kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Lost-Frequencies-ft-Calum-Scott-Where-Are-You-Now.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-06-21T15:58:04.000000Z
#   Duration: 00:02:53.29, start: 0.000000, bitrate: 300 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 168 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2022-06-21T15:58:04.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/21/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-06-21T15:58:04.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/21/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140358000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/ft_calum_scott_where_are_you_now/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn, 2 tbc (default)
#     Metadata:
#       creation_time   : 2022-06-21T15:58:04.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/21/2022.
#       encoder         : Lavc58.54.100 png
# frame=  347 fps=0.0 q=-0.0 Lsize=N/A time=00:02:53.50 bitrate=N/A speed= 280x
# video:50083kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Lil-Nas-X-MONTERO-Call-Me-By-Your-Name-.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2021-09-25T08:23:11.000000Z
#   Duration: 00:03:09.82, start: 0.000000, bitrate: 571 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 440 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2021-09-25T08:23:11.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/25/2021.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2021-09-25T08:23:11.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/25/2021.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140948000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/x_montero_call_me_by_your_name_/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn, 2 tbc (default)
#     Metadata:
#       creation_time   : 2021-09-25T08:23:11.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/25/2021.
#       encoder         : Lavc58.54.100 png
# frame=  380 fps=0.0 q=-0.0 Lsize=N/A time=00:03:10.00 bitrate=N/A speed= 196x
# video:118073kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Billie-Eilish-Khalid-lovely.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-09-23T12:49:33.000000Z
#   Duration: 00:03:20.48, start: 0.000000, bitrate: 165 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 114 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2022-09-23T12:49:33.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/23/2022.
#     Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 47 kb/s (default)
#     Metadata:
#       creation_time   : 2022-09-23T12:49:33.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 09/23/2022.
# Stream mapping:
# ...
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/music_sessions_53/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       encoder         : Lavc58.54.100 png
# frame=  218 fps=0.0 q=-0.0 Lsize=N/A time=00:03:38.00 bitrate=N/A speed= 377x
# video:49366kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Khalid-Young-Dumb-Broke.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-05-28T19:39:01.000000Z
#   Duration: 00:04:07.06, start: 0.000000, bitrate: 319 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 188 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2023-05-28T19:39:01.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/28/2023.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-28T19:39:01.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/28/2023.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x130458000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/dumb_broke/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2023-05-28T19:39:01.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/28/2023.
#       encoder         : Lavc58.54.100 png
# frame=  247 fps=0.0 q=-0.0 Lsize=N/A time=00:04:07.00 bitrate=N/A speed= 354x
# video:61015kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/SZA-Good-Days.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-06-06T00:30:51.000000Z
#   Duration: 00:05:39.06, start: 0.000000, bitrate: 329 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 198 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2023-06-06T00:30:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/05/2023.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2023-06-06T00:30:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/05/2023.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1183c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/sza_good_days/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 0.50 fps, 0.50 tbn, 0.50 tbc (default)
#     Metadata:
#       creation_time   : 2023-06-06T00:30:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/05/2023.
#       encoder         : Lavc58.54.100 png
# frame=  170 fps=0.0 q=-0.0 Lsize=N/A time=00:05:40.00 bitrate=N/A speed= 460x
# video:49274kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Zedd-Alessia-Cara-Stay.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2020-02-29T12:43:25.000000Z
#   Duration: 00:03:33.07, start: 0.000000, bitrate: 244 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 193 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2020-02-29T12:43:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/29/2020.
#     Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 47 kb/s (default)
#     Metadata:
#       creation_time   : 2020-02-29T12:43:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/29/2020.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1082e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/cara_stay/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2020-02-29T12:43:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/29/2020.
#       encoder         : Lavc58.54.100 png
# frame=  213 fps=0.0 q=-0.0 Lsize=N/A time=00:03:33.00 bitrate=N/A speed= 464x
# video:20679kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/24kGoldn-Mood.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-06-16T10:07:43.000000Z
#   Duration: 00:02:30.33, start: 0.000000, bitrate: 409 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 278 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2022-06-16T10:07:43.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/16/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-06-16T10:07:43.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/16/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1384b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/24kgoldn_mood/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn, 2 tbc (default)
#     Metadata:
#       creation_time   : 2022-06-16T10:07:43.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/16/2022.
#       encoder         : Lavc58.54.100 png
# frame=  301 fps=0.0 q=-0.0 Lsize=N/A time=00:02:30.50 bitrate=N/A speed= 232x
# video:70241kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/videos/Conan-Gray-Heather.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2020-08-29T12:35:49.000000Z
#   Duration: 00:03:25.13, start: 0.000000, bitrate: 191 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 140 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-08-29T12:35:49.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/29/2020.
#     Stream #0:1(und): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 47 kb/s (default)
#     Metadata:
#       creation_time   : 2020-08-29T12:35:49.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/29/2020.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '/Users/stamatiosorphanos/Documents/MultiModal-Deep-Learning/MultiModal/frames/conan_gray_heather/frame_%d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 1 fps, 1 tbn, 1 tbc (default)
#     Metadata:
#       creation_time   : 2020-08-29T12:35:49.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/29/2020.
#       encoder         : Lavc58.54.100 png
# frame=  205 fps=0.0 q=-0.0 Lsize=N/A time=00:03:25.00 bitrate=N/A speed= 325x
# video:43532kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %% [markdown]
# ## Create the Train-Test Split in the data above
#
# In order to load the data correctly we need to create a train-test split of the
# datasets.

# %%
train_folder = 'train'  # Path to the train folder
test_folder = 'test'  # Path to the test folder
split_ratio = 0.9  # Train-test split ratio

# Create train and test folders if they don't exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Get the list of video folders in the data folder
video_folders = [folder for folder in os.listdir(frames_path) if os.path.isdir(os.path.join(frames_path, folder))]

# Process each video folder
for video_folder in video_folders:
    video_path = os.path.join(frames_path, video_folder)

    # Create train and test sub-folders for the current video folder
    train_video_folder = os.path.join(train_folder, video_folder)
    test_video_folder = os.path.join(test_folder, video_folder)
    os.makedirs(train_video_folder, exist_ok=True)
    os.makedirs(test_video_folder, exist_ok=True)

    # Get the list of image files in the current video folder
    image_files = [file for file in os.listdir(video_path) if os.path.isfile(os.path.join(video_path, file))]

    # Shuffle the image files randomly
    random.shuffle(image_files)

    # Calculate the split indices based on the split ratio
    split_index = int(len(image_files) * split_ratio)

    # Move files to the train folder
    for file in image_files[:split_index]:
        file_name, file_ext = os.path.splitext(file)
        frame_number  = file_name.split('_')[1]
        new_file_name = f'{video_folder}_{frame_number}{file_ext}'
        shutil.move(os.path.join(video_path, file), os.path.join(train_video_folder, new_file_name))

    # Move files to the test folder
    for file in image_files[split_index:]:
        file_name, file_ext = os.path.splitext(file)
        frame_number  = file_name.split('_')[1]
        new_file_name = f'{video_folder}_{frame_number}{file_ext}'
        shutil.move(os.path.join(video_path, file), os.path.join(test_video_folder, new_file_name))

# %% [markdown]
# ### Remove frames folder

# %%
# After creating the train and test folder we can delete the frames folder
shutil.rmtree(frames_path)
